# %%
import pandas as pd

# %%
matches = pd.read_csv('matches.csv', index_col = 0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2024-08-18  16:30  Premier League  Matchweek 1  Sun  Away      W  2.0  0.0
# 2  2024-08-24  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  1.0
# 3  2024-08-31  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  1.0
# 0  2024-08-17  15:00  Premier League  Matchweek 1  Sat  Away      W  3.0  0.0
# 1  2024-08-24  12:30  Premier League  Matchweek 2  Sat  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 1         Chelsea  ...  Match Report    NaN  11.0  5.0  19.1  0.0  0     0
# 2    Ipswich Town  ...  Match Report    NaN  13.0  4.0  17.8  1.0  1     1
# 3        West Ham  ...  Match Report    NaN  23.0  8.0  15.0  1.0  0     0
# 0         Everton  ...  Match Report    NaN  10.0  5.0  13.8  0.0  0     0
# 1  Manchester Utd  ...  Match Report    NaN  14.0  4.0  14.2  1.0  0     0
#
#   season                      team
# 1   2025           Manchester City
# 2   2025           Manchester City
# 3   2025           Manchester City
# 0   2025  Brighton and Hove Albion
# 1   2025  Brighton and Hove Albion
#
# [5 rows x 28 columns]

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
matches['date'] = pd.to_datetime(matches['date'])

# %%
matches['venue_code'] = matches['venue'].astype('category').cat.codes

# %%
matches['opp_code'] = matches['opponent'].astype('category').cat.codes

# %%
matches['hour'] = matches['time'].str.replace(':.+','', regex=True).astype('int')

# %%
matches['day_code'] = matches['date'].dt.dayofweek

# %%
matches['target'] = (matches['result'] == 'W').astype('int')

# %%
# %pip install scikit-learn
from sklearn.ensemble import RandomForestClassifier
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/VDas23/Library/Python/3.10/lib/python/site-packages (1.5.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/VDas23/Library/Python/3.10/lib/python/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/VDas23/Library/Python/3.10/lib/python/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /Users/VDas23/Library/Python/3.10/lib/python/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/VDas23/Library/Python/3.10/lib/python/site-packages (from scikit-learn) (3.5.0)
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches['date'] < '2022-05-22']

# %%
test = matches[matches['date'] > '2022-05-22']

# %%
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test['target'], preds)

# %%
acc
# Out:
# 0.5974683544303797

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction=preds))

# %%
combined
# Out:
#     actual  prediction
# 1        1           0
# 2        1           1
# 3        1           1
# 0        1           0
# 1        1           0
# ..     ...         ...
# 42       0           1
# 43       0           0
# 44       0           1
# 45       0           0
# 46       0           0
#
# [1580 rows x 2 columns]

# %%
pd.crosstab(index=combined['actual'], columns=combined['prediction'])
# Out:
# prediction    0    1
# actual
# 0           751  215
# 1           421  193

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test['target'], preds)
# Out:
# 0.4730392156862745

# %%
grouped_matches = matches.groupby('team')

# %%
group = grouped_matches.get_group('Manchester United')

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2024-08-16  20:00  Premier League   Matchweek 1  Fri  Home      W  1.0
# 2  2024-08-24  12:30  Premier League   Matchweek 2  Sat  Away      L  1.0
# 3  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Home      L  0.0
# 0  2023-08-14  20:00  Premier League   Matchweek 1  Mon  Home      W  1.0
# 1  2023-08-19  17:30  Premier League   Matchweek 2  Sat  Away      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 55 2021-05-09  14:05  Premier League  Matchweek 35  Sun  Away      W  3.0
# 56 2021-05-11  18:00  Premier League  Matchweek 36  Tue  Home      L  1.0
# 57 2021-05-13  20:15  Premier League  Matchweek 34  Thu  Home      L  2.0
# 58 2021-05-18  18:00  Premier League  Matchweek 37  Tue  Home      D  1.0
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Away      W  2.0
#
#      ga        opponent  ...   fk  pk  pkatt  season               team  \
# 1   0.0          Fulham  ...  0.0   0      0    2025  Manchester United
# 2   2.0        Brighton  ...  0.0   0      0    2025  Manchester United
# 3   3.0       Liverpool  ...  0.0   0      0    2025  Manchester United
# 0   0.0          Wolves  ...  0.0   0      0    2024  Manchester United
# 1   2.0       Tottenham  ...  1.0   0      0    2024  Manchester United
# ..  ...             ...  ...  ...  ..    ...     ...                ...
# 55  1.0     Aston Villa  ...  0.0   1      1    2021  Manchester United
# 56  2.0  Leicester City  ...  0.0   0      0    2021  Manchester United
# 57  4.0       Liverpool  ...  1.0   0      0    2021  Manchester United
# 58  1.0          Fulham  ...  2.0   0      0    2021  Manchester United
# 59  1.0          Wolves  ...  0.0   1      1    2021  Manchester United
#
#    venue_code opp_code hour day_code  target
# 1           1        9   20        4       1
# 2           0        4   12        5       0
# 3           1       13   16        6       0
# 0           1       26   20        0       1
# 1           0       22   17        5       0
# ..        ...      ...  ...      ...     ...
# 55          0        1   14        6       1
# 56          1       12   18        1       0
# 57          1       13   20        3       0
# 58          1        9   18        1       0
# 59          0       26   16        6       1
#
# [155 rows x 33 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values('date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ['gf','ga','sh', 'sot','dist', 'fk', 'pk', 'pkatt']
new_cols = [f'{c}_rolling' for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-17  20:00  Premier League   Matchweek 5  Sat  Away      W  4.0
# 7  2020-10-24  17:30  Premier League   Matchweek 6  Sat  Home      D  0.0
# 9  2020-11-01  16:30  Premier League   Matchweek 7  Sun  Home      L  0.0
# 11 2020-11-07  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 12 2020-11-21  20:00  Premier League   Matchweek 9  Sat  Home      W  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 49 2024-05-15  20:00  Premier League  Matchweek 34  Wed  Home      W  3.0
# 50 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      W  2.0
# 1  2024-08-16  20:00  Premier League   Matchweek 1  Fri  Home      W  1.0
# 2  2024-08-24  12:30  Premier League   Matchweek 2  Sat  Away      L  1.0
# 3  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Home      L  0.0
#
#      ga       opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 5   1.0  Newcastle Utd  ...         5       1    1.666667    3.666667
# 7   0.0        Chelsea  ...         5       0    2.666667    3.000000
# 9   1.0        Arsenal  ...         6       0    1.666667    2.333333
# 11  1.0        Everton  ...         5       1    1.333333    0.666667
# 12  0.0      West Brom  ...         5       1    1.000000    0.666667
# ..  ...            ...  ...       ...     ...         ...         ...
# 49  2.0  Newcastle Utd  ...         2       1    0.333333    2.000000
# 50  0.0       Brighton  ...         6       1    1.000000    2.333333
# 1   0.0         Fulham  ...         4       1    1.666667    1.000000
# 2   2.0       Brighton  ...         5       0    2.000000    0.666667
# 3   3.0      Liverpool  ...         6       0    1.333333    0.666667
#
#    sh_rolling sot_rolling dist_rolling fk_rolling pk_rolling  pkatt_rolling
# 5    9.000000    2.333333    21.266667   0.333333   0.666667       0.666667
# 7   12.333333    4.666667    21.366667   0.000000   0.666667       1.000000
# 9   15.000000    5.333333    21.266667   0.000000   0.333333       0.666667
# 11  16.333333    5.666667    19.433333   0.000000   0.000000       0.333333
# 12  11.666667    3.666667    19.633333   0.666667   0.000000       0.000000
# ..        ...         ...          ...        ...        ...            ...
# 49  16.000000    4.666667    19.200000   0.333333   0.000000       0.000000
# 50  12.666667    4.000000    18.266667   0.333333   0.000000       0.000000
# 1   14.000000    4.666667    18.366667   0.000000   0.000000       0.000000
# 2   14.000000    5.666667    16.600000   0.000000   0.000000       0.000000
# 3   12.000000    4.000000    16.966667   0.000000   0.000000       0.000000
#
# [152 rows x 41 columns]

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# /var/folders/1s/v5yx4rxx4yl2vxprxkcr5y6w0000gp/T/ipykernel_67013/1214488446.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data['date'] < '2022-05-22']
    test = data[data['date'] > '2022-05-22']
    rf.fit(train[predictors], train['target'])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test['target'], prediction=preds), index=test.index)
    precision = precision_score(test['target'], preds)
    return combined, precision

# %%
combined, precision, = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5583126550868487

# %%
combined = combined.merge(matches_rolling[['date', 'team', 'opponent', 'result']], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  prediction       date                     team         opponent  \
# 73         1           0 2022-08-05                  Arsenal   Crystal Palace
# 74         1           0 2022-08-13                  Arsenal   Leicester City
# 75         1           1 2022-08-20                  Arsenal      Bournemouth
# 76         1           0 2022-08-27                  Arsenal           Fulham
# 77         1           1 2022-08-31                  Arsenal      Aston Villa
# ...      ...         ...        ...                      ...              ...
# 3011       0           0 2024-05-11  Wolverhampton Wanderers   Crystal Palace
# 3012       0           0 2024-05-19  Wolverhampton Wanderers        Liverpool
# 3013       0           0 2024-08-17  Wolverhampton Wanderers          Arsenal
# 3014       0           0 2024-08-25  Wolverhampton Wanderers          Chelsea
# 3015       0           0 2024-08-31  Wolverhampton Wanderers  Nott'ham Forest
#
#      result
# 73        W
# 74        W
# 75        W
# 76        W
# 77        W
# ...     ...
# 3011      L
# 3012      L
# 3013      L
# 3014      L
# 3015      D
#
# [1568 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    'Brighton and Hove Albion': 'Brighton',
    'Manchester United' : 'Manchester Utd',
    'Newcastle United': 'Newcastle Utd',
    'Tottenham Hotspur': 'Tottenham',
    'West Ham United' : 'West Ham',
    'Wolverhampton Wanderers': 'Wolves'
}
mapping = MissingDict(**map_values)

# %%
combined['new_team'] = combined['team'].map(mapping)

# %%
merged =  combined.merge(combined, left_on=['date', 'new_team'], right_on=['date', 'opponent'])

# %%
merged
# Out:
#       actual_x  prediction_x       date                   team_x  \
# 0            1             0 2022-08-05                  Arsenal
# 1            1             0 2022-08-13                  Arsenal
# 2            1             0 2022-08-27                  Arsenal
# 3            1             1 2022-08-31                  Arsenal
# 4            0             1 2022-09-04                  Arsenal
# ...        ...           ...        ...                      ...
# 1437         0             0 2024-05-11  Wolverhampton Wanderers
# 1438         0             0 2024-05-19  Wolverhampton Wanderers
# 1439         0             0 2024-08-17  Wolverhampton Wanderers
# 1440         0             0 2024-08-25  Wolverhampton Wanderers
# 1441         0             0 2024-08-31  Wolverhampton Wanderers
#
#            opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0      Crystal Palace        W    Arsenal         0             0
# 1      Leicester City        W    Arsenal         0             0
# 2              Fulham        W    Arsenal         0             0
# 3         Aston Villa        W    Arsenal         0             0
# 4      Manchester Utd        L    Arsenal         1             0
# ...               ...      ...        ...       ...           ...
# 1437   Crystal Palace        L     Wolves         1             0
# 1438        Liverpool        L     Wolves         1             1
# 1439          Arsenal        L     Wolves         1             1
# 1440          Chelsea        L     Wolves         1             0
# 1441  Nott'ham Forest        D     Wolves         0             1
#
#                  team_y opponent_y result_y         new_team_y
# 0        Crystal Palace    Arsenal        L     Crystal Palace
# 1        Leicester City    Arsenal        L     Leicester City
# 2                Fulham    Arsenal        L             Fulham
# 3           Aston Villa    Arsenal        L        Aston Villa
# 4     Manchester United    Arsenal        W     Manchester Utd
# ...                 ...        ...      ...                ...
# 1437     Crystal Palace     Wolves        W     Crystal Palace
# 1438          Liverpool     Wolves        W          Liverpool
# 1439            Arsenal     Wolves        W            Arsenal
# 1440            Chelsea     Wolves        W            Chelsea
# 1441  Nottingham Forest     Wolves        D  Nottingham Forest
#
# [1442 rows x 13 columns]

# %%
merged[(merged['prediction_x'] == 1) & (merged['prediction_y'] == 0)]['actual_x'].value_counts()
# Out:
# actual_x
# 1    194
# 0    138
# Name: count, dtype: int64

# %%
194 / (194 + 138)
# Out:
# 0.5843373493975904
